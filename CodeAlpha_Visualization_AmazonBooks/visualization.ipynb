# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("books.csv")
df.head()
# Out:
#                                                Title     Rating     Price
# 0  Fun Coloring Book for Kids - Hours of Creative...        4.5   ₹199.00
# 1  PROFESSIONAL'S AIBE Exam 25 Bare Acts Set with...        3.9  No Price
# 2  My First Library: Boxset of 10 Board Books for...        4.5  No Price
# 3  Examcart KVS & NVS Tier-1 Recruitment Exam Boo...  No Rating  No Price
# 4  AIBE Bare Acts without Notes | 25 Books Set Co...        4.2  No Price

# %%
df['Price'] = df['Price'].str.replace("₹", "").str.replace(",", "")
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price'], kde=True)
plt.title("Price Distribution of Books")
plt.xlabel("Price (₹)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Rating'], kde=True)
plt.title("Rating Distribution of Books")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['Price'], y=df['Rating'])
plt.title("Price vs Rating")
plt.xlabel("Price (₹)")
plt.ylabel("Rating")
plt.show()

# %%
top10 = df.nlargest(10, 'Price')

plt.figure(figsize=(10,6))
sns.barplot(x='Price', y='Title', data=top10)
plt.title("Top 10 Most Expensive Books")
plt.xlabel("Price (₹)")
plt.ylabel("Book Title")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Rating'])
plt.title("Count of Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.show()

# %%
print("📌 INSIGHTS")
print("-----------------------------")
print("Average Price:", df['Price'].mean())
print("Highest Price:", df['Price'].max())
print("Lowest Price:", df['Price'].min())
print("Average Rating:", df['Rating'].mean())
# Out:
# 📌 INSIGHTS
# -----------------------------
# Average Price: 199.0
# Highest Price: 199.0
# Lowest Price: 199.0
# Average Rating: 4.45
